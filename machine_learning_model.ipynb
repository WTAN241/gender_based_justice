# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(Path('/Users/sohyunchoi/Desktop/Bootcamp/final_project/oecd_gender_converted.csv'))
df.head(10)
# Out:
#           Country  OECD  Practice  Child_Marriage_Law  \
# 0       Australia     1      38.8                0.50
# 1         Austria     1      35.1                0.50
# 2         Belgium     1      36.2                0.50
# 3          Canada     1      35.5                0.75
# 4           Chile     1      35.4                0.50
# 5        Colombia     1      38.2                0.50
# 6      Costa Rica     1      40.4                0.50
# 7  Czech Republic     1      34.7                0.50
# 8         Denmark     1      36.1                0.00
# 9         Estonia     1      38.1                0.50
#
#    Household_Responsibilities_Law Household_Responsibilities_Attitude  \
# 0                            0.50                                21.1
# 1                            0.50                                58.3
# 2                            0.50                                  32
# 3                            0.50                                27.7
# ...
