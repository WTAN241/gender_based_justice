# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Resources/coverted_oecd_data.csv')

# %%
df
# Out:
#        Country  OECD  Child_marriage_Law  Child_marriage_Practice  \
# 0    Australia     1                0.50                      0.6
# 1      Austria     1                0.50                      2.8
# 2      Belgium     1                0.50                      2.2
# 3       Canada     1                0.75                      1.7
# 4        Chile     1                0.50                      5.9
# ..         ...   ...                 ...                      ...
# 175  Venezuela     0                0.50                     16.4
# 176   Viet Nam     0                0.25                     10.3
# 177      Yemen     0                0.75                     17.2
# 178     Zambia     0                0.50                     18.6
# 179   Zimbabwe     0                0.50                     22.9
#
#      Household_responsibilities_Law  Divorce_Law  Violence_against_women_Law  \
# 0                              0.50         0.00                        0.75
# ...

# %%
df["Child_marriage_Practice"].describe()
# Out:
# count    180.000000
# mean      11.823889
# std       11.785178
# min        0.000000
# 25%        2.750000
# 50%        7.950000
# 75%       18.375000
# max       61.900000
# Name: Child_marriage_Practice, dtype: float64
